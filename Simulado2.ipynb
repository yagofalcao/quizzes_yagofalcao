# %%
import numpy as np
import pandas as pd
import unittest as ut

# %% [markdown]
# 1. Numpy:
#
# a) Escreva um programa NumPy para calcular a decomposição QR de uma determinada matriz
#
# b) Escreva um programa NumPy para obter todas as diagonais 2D de uma matriz numpy 3D
#
# c) Escreva um programa NumPy para calcular xy, em elementos, onde x, y são duas matrizes fornecidas
#
# 2. Pandas:
#
# a) Como obter os itens da série A não presentes na série B?
#
# b) Como obter o grupo específico de um groupby dataframe pela key?
#
# c) Como criar uma coluna contendo o mínimo dividido pelo máximo de cada linha?
#
# 3. unittest:
#
# a) Porque fazer testes para um programa?
#
# b) Execute e explique o que os testes abaixo fazem:
#
# ```python
# import unittest
#
# class TestStringMethods(unittest.TestCase):
#
#     def setUp(self):
#         pass
#
#     # Returns True if the string contains 4 a.
#     def test_strings_a(self):
#         self.assertEqual( 'a'*4, 'aaaa')
#
#     # Returns True if the string is in upper case.
#     def test_upper(self):
#         self.assertEqual('foo'.upper(), 'FOO')
#
#     # Returns TRUE if the string is in uppercase
#     # else returns False.
#     def test_isupper(self):
#         self.assertTrue('FOO'.isupper())
#         self.assertFalse('Foo'.isupper())
#
#     # Returns true if the string is stripped and
#     # matches the given output.
#     def test_strip(self):
#         s = 'geeksforgeeks'
#         self.assertEqual(s.strip('geek'), 'sforgeeks')
#
#     # Returns true if the string splits and matches
#     # the given output.
#     def test_split(self):
#         s = 'hello world'
#         self.assertEqual(s.split(), ['hello', 'world'])
#         with self.assertRaises(TypeError):
#             s.split(2)
#
# if __name__ == '__main__':
#     unittest.main()
#     ```
# c) Codifique (em um arquivo diferente) pelo menos 5 testes diferentes por método da classe abaixo:
#
# ```python
#
# class Calculator:
#     """ A simple calculator App"""
#
#     def add(x, y):
#         """Add Function"""
#         return x + y
#
#     def subtract(x, y):
#         """Subtract Function"""
#         return x - y
#
#     def multiply(x, y):
#         """Multiply Function"""
#         return x * y
#
#     def divide(x, y):
#         """Divide Function"""
#         if y == 0:
#             raise ValueError('Can not divide by zero!')
#
#         return x / y
#
# ```
#
# 4. Extra:
#
# Um astrólogo chamado Carlos encontra uma estrela. Feliz da vida pois acredita ser do tipo B, uma classe de estrelas mais raras, decide nomeá-la Patrícia III, sua antiga namorada. Patricia III é observada usando um telescópio com erro de medição conhecido. Em dias abertos, este erro é N(0,1), caso contrátio N(0,100). Estrelas do tipo B são caracterizadas por brilho $\theta$ acima de 10 (unidades).
#
# Dados as hipóteses:
#
# H0: $\theta$ <= 10
#
# H1: $\theta$ > 10
#
# T = (média das medições - u)/d, onde u é a média da distribuição e d o desvio padrão
#
# H0 é rejeitado se T > $\alpha$
#
# a) Faça um programa que gere 16 medições em dias abertos e com unittest teste a hipótese ($\alpha$ = 0.5)
#
# b) Faça um programa que gere 16 medições em dias fechados e com unittest teste a hipótese ($\alpha$ = 0.5)
#
# c) Faça um programa que gere n medições em dias abertos e m medições em dias fechados e com unittest teste a hipótese para ambos os casos. Parâmetros da função (n, m, $\alpha$)
#
# Obs: o programa não retorna resultado, ou é executado normalmente ou falha.
